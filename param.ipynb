# %%
datasets=[
    {
        "file_name":"orders"
    },
    {
        "file_name":"buyer"
    },
    {
        "file_name":"products"
    }
]

# %%
dbutils.jobs.taskValues.set("output_datasets",datasets)
